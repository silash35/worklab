# %% [markdown]
# # Equipe:
#
# #### Equipe formada pelos alunos Silas Henrique Alves Araújo, Ecília Silva de Oliveira e Andreza Ísis Santos Costa.

# %% [markdown]
# # Questão 1
#
# Um reator contínuo de tanque agitado, também chamado de CSTR (continuous stirred-tank reactor), é um tipo de reator ideal e comum em engenharia química e modelado através de balanços de massa e energia.
#
# Dada uma reação A → B exotérmica realizada em um CSTR que possui uma camisa por onde passa um fluído refrigerante, através dos balanços de massa energia obtém-se a seguinte representação:
# \begin{align}
# \begin{cases}
# \frac{dC*A(t)}{dt} = -k_0 \cdot C_A(t) \cdot e^{-E_R/T(t)} + \frac{Q_f(t) \cdot C*{Af} - Q \cdot C*A(t)}{a \cdot h(t)} \\
# \frac{dT(t)}{dt} = \frac{-k_0 \cdot C_A(t) \cdot \Delta H \cdot e^{-E_R/T(t)}}{\rho C_p} + \frac{Q_f \cdot T_f - Q \cdot T(t)}{a \cdot h(t)} + \frac{U*{a*c} \cdot (T_c(t) - T(t))}{\rho C_p \cdot a \cdot h(t)} \\
# \frac{dT_c(t)}{dt} = \frac{Q_c \cdot (T*{cf} - T*c(t))}{V_c} + \frac{U*{a*c} \cdot (T(t) - T_c(t))}{\rho C*{pc} \cdot V_c} \\
# \frac{dh(t)}{dt} = \frac{Q_f(t) - Q}{a}
# \end{cases}
# \end{align}
#
# onde: $a$ = 0.1666 m$^2$, $V_c$ = 0.01 m$^3$, $U_{a_c}$ = 5$\times$10$^4$ J/(min$\cdot$K), $\rho C_p$ = 2.39$\times$10$^5$ J/(m$^3 \cdot $K), $\rho C_{pc}$ = 4.175$\times$10$^6$ J/(m$^3 \cdot $K) \), $k_0$ = 7.2$\times$10$^{10}$ min$^{-1}$, $E_R$ = 8750 K, $\Delta H$ = -5$\times$10$^4$ J/mol, $Q$ = 0.1 m$^3$/min, $C_{Af}$ = 1000 mol/m$^3$, $T_f$ = 320 K, $Q_c$ = 0.015 m$^3$/min, $T_{cf}$ = 300 K, $0 \leq h(t) \leq 2.0$m

# %% [markdown]
# ## Item 1.1
#
# Avalie o estacionário do sistema para um valor de vazão de alimentação $Q_f(0) = 0.1$ m$^3$/min e $h(0)$ = 1.0 m. Em seguida, simule o comportamento do reator no intervalo de 0 ≤ t ≤ 50 min, aplicando um degrau na vazão de alimentação
# $Q_f(t) = \begin{cases}
# 0.1 & t < 5 \text{ min} \\
# 0.11 & t \geq 5 \text{ min}
# \end{cases}$,
# sabendo que o sistema parte do estado estacionário.
#
# Apresente os gráficos de concentração do reagente $C_A(t)$, temperatura interna do reator $T(t)$, temperatura da camisa $T_c(t)$ e nível no interior do CSTR $h(t)$ e discuta os resultados

# %% [markdown]
# ### Importando bibliotecas e definindo as constantes

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.optimize import fsolve

a = 0.1666  # m^2
Vc = 0.01  # m^3
Uac = 5e4  # J/(min⋅K)
rhoCp = 2.39e5  # J/(m^3⋅K)
rhoCpc = 4.175e6  # J/(m^3⋅K)
k0 = 7.2e10  # min^-1
ER = 8750  # K
dH = -5e4  # J/mol
CAf = 1000  # mol/m^3
Tf = 320  # K
Qc = 0.015  # m^3/min
Tcf = 300  # K

# %% [markdown]
# ### Avaliando o estado estacionário do sistema
#
# O estado estacionário é o estado em que todas as derivadas são zero. Sendo assim, podemos resolver o sistema de equações diferenciais como um sistema de equações comuns, utilizando a função fsolve.

# %%
# Definindo o sistema de equações para achar a raiz.
def sistema(Y, Qf, Q):
    CA, T, Tc = Y

    # Se h(0) = 1 e dhdt = 0 desdo começo. Então h é constante e não varia.
    h = 1  # m

    dCAdt = -k0 * CA * np.exp(-ER / T) + Qf * CAf / (a * h) - Q * CA / (a * h)
    dTdt = (
        (-k0 * CA * dH * np.exp(-ER / T)) / (rhoCp)
        + (Qf * Tf - Q * T) / (a * h)
        + (Uac * (Tc - T)) / (rhoCp * a * h)
    )
    dTcdt = Qc * (Tcf - Tc) / Vc + Uac * (T - Tc) / (rhoCpc * Vc)
    # A quarta equação do sistema não é necessária para esse cálculo, pois aqui ela é constante.
    # Perceba que Se Qf é igual a 0.1 que é igual a Q, a derivada de h sempre será zero. Portanto
    # h não varia. E se h(0) é 1, então h sempre será 1.
    # dhdt = (Qf - Q) / a
    return [dCAdt, dTdt, dTcdt]


# dhdt = (Qf - Q) / a
# No estado estacionário dhdt = 0.
# Como Q = 0.1, Qf precisa ser 0.1 também, para todos os valores de t.
# Portanto podemos fixar o valor de Qf e Q.
Q = 0.1  # m^3/min
Qf = 0.1  # m^3/min

# Resolver o sistema utilizando a função fsolve
Y0 = [20, 400, 350]  # Estimativas iniciais
Y_etc = fsolve(sistema, Y0, args=(Qf, Q))

# Extração dos valores no estado estacionário
CA_etc = Y_etc[0]
T_etc = Y_etc[1]
Tc_etc = Y_etc[2]
h_etc = 1  # h(0) = 1, mas como a derivada é zero, ele sempre será 1

# Valores de estado estacionário
print("Solução do sistema:")
print(f"  CA_etc: {CA_etc}")
print(f"  T_etc: {T_etc}")
print(f"  Tc_etc: {Tc_etc}")
print(f"  h_etc: {h_etc}")

# Conferindo se o cálculo do estado estacionário foi correto
# Os valores dentro do array precisam ser próximos de zero
print("Teste da solução do sistema:", sistema(Y_etc, Qf, Q))
# Out:
# Solução do sistema:
#   CA_etc: 20.86863190620163
#   T_etc: 403.9342951805787
#   Tc_etc: 346.1417514675155
#   h_etc: 1
# Teste da solução do sistema: [1.7340795466225245e-11, -3.623767952376511e-12, 1.4210854715202004e-14]

# %% [markdown]
# ### Simulando o comportamento do reator

# %%
# Definido o sistema de Equações diferenciais
def Tanque(t, Y, Qf_func, Q_func):
    CA, T, Tc, h = Y

    Qf = Qf_func(t)
    Q = Q_func(t, h)

    dCAdt = -k0 * CA * np.exp(-ER / T) + Qf * CAf / (a * h) - Q * CA / (a * h)
    dTdt = (
        -k0 * CA * dH * np.exp(-ER / T) / (rhoCp)
        + (Qf * Tf - Q * T) / (a * h)
        + Uac * (Tc - T) / (rhoCp * a * h)
    )
    dTcdt = Qc * (Tcf - Tc) / Vc + Uac * (T - Tc) / (rhoCpc * Vc)
    dhdt = (Qf - Q) / a
    return [dCAdt, dTdt, dTcdt, dhdt]


# Definido a função de vazão de alimentação Qf(t)
def Qf_degrau(t):
    return 0.1 if t < 5 else 0.11


# Definindo a função de vazão de descarga Q(t)
def Q_func(t, h):
    return Q  # m^3/min


# Resolver o sistema com as condições iniciais (valores do estado estacionário) e utilizando Qf_degrau como função de vazão de alimentação
Y = solve_ivp(Tanque, [0, 50], [CA_etc, T_etc, Tc_etc, h_etc], args=(Qf_degrau, Q_func))


# Extração dos valores
t = Y.t
CA = Y.y[0]
T = Y.y[1]
Tc = Y.y[2]
h = Y.y[3]

# Plotagem dos resultados
fig, axs = plt.subplots(2, 2, figsize=(12, 5), layout="constrained")

axs[0, 0].plot(t, CA, "b-", label="CA(t)")
axs[0, 0].set_ylabel("Concentração de A (mol/m^3)")
axs[0, 0].set_xlabel("Tempo (min)")
axs[0, 0].legend()
axs[0, 0].grid()

axs[0, 1].plot(t, T, "r-", label="T(t)")
axs[0, 1].set_ylabel("Temperatura do Reator (K)")
axs[0, 1].set_xlabel("Tempo (min)")
axs[0, 1].legend()
axs[0, 1].grid()

axs[1, 0].plot(t, Tc, "g-", label="Tc(t)")
axs[1, 0].set_ylabel("Temperatura da Camisa (K)")
axs[1, 0].set_xlabel("Tempo (min)")
axs[1, 0].legend()
axs[1, 0].grid()

axs[1, 1].plot(t, h, "k-", label="h(t)")
axs[1, 1].set_ylabel("Nível no tanque CSTR (m)")
axs[1, 1].set_xlabel("Tempo (min)")
axs[1, 1].legend()
axs[1, 1].grid()

plt.show()

# %% [markdown]
# ### Análise dos resultados e gráficos
#
# Analisando cada gráfico para entender o comportamento do sistema após o degrau na vazão de alimentação, percebemos inicialmente a concentração de A é alta, mas cai rapidamente após o degrau na vazão de alimentação, estabilizando-se em um valor mais baixo. Isso ocorre porque o aumento na vazão de alimentação traz mais reagente ao sistema, aumentando a taxa de reação e consequentemente consumindo mais A.
#
# Já na temperatura do reator aumenta significativamente após o aumento da vazão de alimentação. Isso pode ser atribuído ao fato de que a reação é exotérmica. Com mais reagente disponível devido ao aumento da vazão, a taxa de reação aumenta, liberando mais calor e elevando a temperatura do sistema.
#
# Em Tc(t) observamos que inicialmente aumenta para compensar o calor gerado pela reação. A temperatura estabiliza-se depois, sugerindo que o sistema de controle da camisa está trabalhando para manter uma temperatura constante para a remoção eficiente de calor do reator.
#
# E por fim, Nível no Tanque (h(t)) no reator aumenta ao longo do tempo, o que é esperado com o aumento da vazão de alimentação. Como o sistema parte de um estado estacionário e a vazão de saída não mudou, o aumento da vazão de entrada resulta em um acúmulo de material no reator, elevando o nível.
#
# Efeito do Degrau na Vazão de Alimentação O aumento de 0,10 para 0,11 m³/min provoca uma série de mudanças no sistema. A concentração de A diminui, enquanto a temperatura do reator aumenta devido à maior taxa de reação. A temperatura da camisa aumenta para dissipar o calor adicional, e o nível de líquido no reator sobe devido ao aumento na vazão de entrada. O controle adequado da temperatura da camisa indica que o sistema de resfriamento está respondendo adequadamente à demanda aumentada de remoção de calor. O aumento no nível do reator sugere que, o sistema precisaria ajustar a vazão de saída para evitar transbordamento ou excesso de pressão no reator. Esse ajuste é o que resolvemos no item 1.2.

# %% [markdown]
# ## Item 1.2
#
# Para garantir melhor estabilidade do processo e evitar que o nível do tanque $(h(t))$ seque ou transborde é adicionado um controlador cujo o objetivo é manter o nível em um valor desejado (Sp = 1.0 m) manipulando a vazão de descarga $Q(t)$.
#
# O Controlador em questão é o famoso proporcional-integral, representado pela seguinte equação:
#
# \begin{align}
# e(t) &= Sp - h(t)\\
# Q(t) &= Q(0) + P\left(e(t) + I\int_0^{t} e(t) \right)
# \end{align}
# onde, $Q(0)$ = 0.1 m$^3$/min, $P$ = -1/6 m$^2$, $I$ = 1.0 min$^{-1}$
#
# Simule o CSTR com o controlador de nível e apresente os gráficos de concentração do reagente $C_A(t)$, temperatura interna do reator $T(t)$, temperatura da camisa $T_c(t)$ e nível no interior do CSTR $h(t)$, comparando com os resultados encontrados no item anterior.

# %% [markdown]
# ### Adicionando o controlador

# %%
# Constantes
Sp = 1  # m
Q0 = 0.1  # m^3/min
P = -1 / 6  # m^2
I = 1  # min^-1


def integral_pontos(x, y):
    """Calcula a integral de um conjunto de pontos "y = f(x)", pelo método dos trapézios"""
    It = 0

    for i in range(len(x) - 1):
        It += ((y[i] + y[i + 1]) * (x[i + 1] - x[i])) / 2

    return It


def erro(h):
    """
    Função e(t). Aqui, em vez de passar o t como argumento,
    estamos passando o valor de h(t) (nível no tanque) diretamente.
    """
    return Sp - h


# Juntas, essas duas listas guardam a função e(t), e serão usadas para o calculo da integral posteriormente.
t_hist = []  # Histórico dos pontos de t
e_hist = []  # Histórico dos pontos de e


def Q_controlador(t, h):
    """Função Q(t), com o controlador proporcional-integral."""

    # Dando acesso as variáveis globais
    global t_hist
    global e_hist

    e = erro(h)

    # Durante a execução do solve_ivp, ele pode ocasionalmente "voltar no tempo"
    # em vez de só avançar. Então não podemos só ir adicionando pontos em t_hist e e_hist.
    # Por exemplo, quando a função Q_controlador é chamada com t=5.0 e em seguida com t=4.0 ainda vamos ter
    # no histórico o ponto t=5.0. Um "ponto do futuro".
    # Esse trecho de código é o responsável por lidar com essa situação.
    while len(t_hist) != 0 and t_hist[-1] >= t:
        # Enquanto a lista não estiver vazia e o t anterior (t_hist[-1]) for maior ou igual o t atual
        # Remova os "pontos do futuro".
        # Isso é necessário para que o calculo da integral seja feita de 0 até o t atual e não conte pontos que estão no futuro
        t_hist.pop()
        e_hist.pop()

    # Adicionar no histórico da função e(t) o ponto atual
    t_hist.append(t)
    e_hist.append(e)

    integral_e = integral_pontos(t_hist, e_hist)

    # Equação do controlador proporcional integral
    return Q0 + P * (e + I * integral_e)


Y_controlador = solve_ivp(
    Tanque,
    [0, 50],
    [CA_etc, T_etc, Tc_etc, h_etc],
    args=(
        Qf_degrau,
        Q_controlador,
    ),
)

# Extração dos valores
t_controlador = Y_controlador.t
CA_controlador = Y_controlador.y[0]
T_controlador = Y_controlador.y[1]
Tc_controlador = Y_controlador.y[2]
h_controlador = Y_controlador.y[3]

# Plotagem dos resultados
fig, axs = plt.subplots(2, 2, figsize=(12, 5), layout="constrained")

axs[0, 0].plot(t, CA, "b-", alpha=0.5, label="CA(t) sem controlador")
axs[0, 0].plot(t_controlador, CA_controlador, "b-", label="CA(t) com controlador")
axs[0, 0].set_ylabel("Concentração de A (mol/m^3)")
axs[0, 0].set_xlabel("Tempo (min)")
axs[0, 0].legend()
axs[0, 0].grid()

axs[0, 1].plot(t, T, "r-", alpha=0.5, label="T(t) sem controlador")
axs[0, 1].plot(t_controlador, T_controlador, "r-", label="T(t) com controlador")
axs[0, 1].set_ylabel("Temperatura do Reator (K)")
axs[0, 1].set_xlabel("Tempo (min)")
axs[0, 1].legend()
axs[0, 1].grid()

axs[1, 0].plot(t, Tc, "g-", alpha=0.5, label="Tc(t) sem controlador")
axs[1, 0].plot(t_controlador, Tc_controlador, "g-", label="Tc(t) com controlador")
axs[1, 0].set_ylabel("Temperatura da Camisa (K)")
axs[1, 0].set_xlabel("Tempo (min)")
axs[1, 0].legend()
axs[1, 0].grid()

axs[1, 1].plot(t, h, "k-", alpha=0.5, label="h(t) sem controlador")
axs[1, 1].plot(t_controlador, h_controlador, "k-", label="h(t) com controlador")
axs[1, 1].set_ylabel("Nível no tanque CSTR (m)")
axs[1, 1].set_xlabel("Tempo (min)")
axs[1, 1].legend()
axs[1, 1].grid()

plt.show()

# %% [markdown]
# ### Análise dos resultados e gráficos
#
# #### No gráfico CA(t), o que percebemos:
#
# Sem o controlador: A concentração do reagente se mantém estável antes de t=5, mas após inserir a pertubação no sistema (aumentando a vazão de entrada) começou a tender a cair rapidamente.
#
# Com o controlador: Aqui, o gráfico começa muito similar, mas após a pertubação o controlador proporcional integral ajusta a vazão de descarga, fazendo com que no final, a concentração de A se estabilize, agora em outro valor (próximo do 17).
#
# #### No gráfico T(t), o que percebemos:
#
# Sem o controlador: A temperatura se mantém estável antes de t=5, e após a pertubação, a temperatura aumenta e se estabiliza em um nível mais alto, mostrando um novo equilíbrio após a inicial perturbação.
#
# Com o controlador: A temperatura também sobe após a pertubação, mas se estabiliza em um valor menor que sem o controlador.
#
# #### No gráfico Tc(t), o que percebemos:
#
# Sem o controlador: Antes de t=5, pelo sistema estar no estado estacionário, o valor de Tc é constante. Após a pertubação a temperatura da camisa aumenta e se estabiliza em por volta de 358K.
#
# Com o controlador: Aqui o comportamento é parecido com o do primeiro gráfico, mas graças a ação do controlador ele estabiliza em uma temperatura mais baixa, um pouco menor que 349K.
#
# #### No gráfico h(t), o que percebemos:
#
# Sem o controlador: O gráfico do nível começa estável, pois o sistema está no estado estacionário, mas após a pertubação a vazão de entrada fica maior que a de saída. Então o tanque começa a encher e transbordar (passar do nível máximo de 2m).
#
# Com o controlador: Agora, com o controlador, o gráfico começa a subir, mas rapidamente o controlador compensa aumentando a vazão de descarga, fazendo com que o nível estabilize no valor de 1 metro.
